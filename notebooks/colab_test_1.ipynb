# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/ISML22/Hybrid Conversion/escape_net_repo/snn_conversion_experiments_2
# Out:
# /content/drive/.shortcut-targets-by-id/1tbtTpZ2_jdSRyeLHX46yXBCCHfU3Q3qs/Hybrid Conversion/escape_net_repo/snn_conversion_experiments_2

# %%
# !python3 src/test_escape_net_SNN.py --dataset_path '/content/drive/MyDrive/ISML22/original_implementations/datasets/ryan_dataset/No_TE/Rat4Training_Fold1.mat' --pretrained_snn '/content/drive/MyDrive/ISML22/Hybrid Conversion/trained_models/snn/snn_escape_net_727_28_1.pth'
# Out:
#  Run on time: 2022-08-22 16:58:49.618944
#
#  Arguments:
# 	 gpu                  : True
# 	 seed                 : 0
# 	 dataset              : RAT4
# 	 batch_size           : 32
# 	 architecture         : ESCAPE_NET
# 	 lr                   : 0.0001
# 	 pretrained_ann       :
# 	 pretrained_snn       : /content/drive/MyDrive/ISML22/Hybrid Conversion/trained_models/snn/snn_escape_net_727_28_1.pth
# 	 log                  : False
# 	 epochs               : 10
# 	 timesteps            : 28
# 	 leak                 : 1.0
# 	 default_threshold    : 1.0
# 	 activation           : Linear
# 	 alpha                : 0.3
# 	 beta                 : 0.01
# 	 optimizer            : Adam
# 	 weight_decay         : 0.0005
# 	 momentum             : 0.95
# 	 amsgrad              : True
# 	 dropout              : 0.2
# 	 kernel_size          : 8
# 	 test_acc_every_batch : False
# 	 train_acc_batches    : 50
# 	 devices              : 0
# ...

# %%
# !python3 src/test_escape_net_SNN.py --dataset_path '/content/drive/MyDrive/ISML22/original_implementations/datasets/ryan_dataset/No_TE/Rat4Training_Fold1.mat' --pretrained_snn '/content/drive/MyDrive/ISML22/Hybrid Conversion/trained_models/snn/snn_escape_net_727_28_2/snn_escape_net_727_28_2.pth'
# Out:
#  Run on time: 2022-08-22 17:01:07.027325
#
#  Arguments:
# 	 gpu                  : True
# 	 seed                 : 0
# 	 dataset              : RAT4
# 	 batch_size           : 32
# 	 architecture         : ESCAPE_NET
# 	 lr                   : 0.0001
# 	 pretrained_ann       :
# 	 pretrained_snn       : /content/drive/MyDrive/ISML22/Hybrid Conversion/trained_models/snn/snn_escape_net_727_28_2/snn_escape_net_727_28_2.pth
# 	 log                  : False
# 	 epochs               : 10
# 	 timesteps            : 28
# 	 leak                 : 1.0
# 	 default_threshold    : 1.0
# 	 activation           : Linear
# 	 alpha                : 0.3
# 	 beta                 : 0.01
# 	 optimizer            : Adam
# 	 weight_decay         : 0.0005
# 	 momentum             : 0.95
# 	 amsgrad              : True
# 	 dropout              : 0.2
# 	 kernel_size          : 8
# 	 test_acc_every_batch : False
# 	 train_acc_batches    : 50
# 	 devices              : 0
# ...
